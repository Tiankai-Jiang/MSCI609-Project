# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../Deliverable 3/csv/data.csv')

# %%
country_code = 'IND'
df_country = df.loc[df['Code'] == country_code].drop(['Annual HPI', 'Country', 'Code', 'Year'], axis = 1)
print(df_country.describe(percentiles=[]).drop(['count', '50%']).transpose().round(3).to_latex(index=True))
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# {} &        mean &         std &        min &          max \\
# \midrule
# Economic growth: the rate of change of real GDP    &       6.845 &       1.266 &       5.02 &        8.500 \\
# Capital investment as percent of GDP               &      34.689 &       4.111 &      30.17 &       40.220 \\
# Exchange rate: local currency units per U.S. do... &      59.015 &       9.084 &      45.73 &       70.420 \\
# Unemployment rate                                  &       5.543 &       0.121 &       5.33 &        5.670 \\
# Terms of trade, base year = 2000                   &      97.596 &       6.501 &      89.99 &      108.190 \\
# Government spending as percent of GDP              &      10.847 &       0.483 &      10.30 &       11.770 \\
# Economic growth forecast                           &       7.113 &       1.644 &       4.18 &       10.260 \\
# ...

# %%
for i in range(3, len(df.columns)):
#     display(df.groupby('Country').agg({df.columns[i]: ['mean', 'min', 'max', 'std']}))
    print(df.groupby('Country').agg({df.columns[i]: ['mean', 'min', 'max', 'std']}).to_latex(index=True))
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# {} & \multicolumn{4}{l}{Economic growth: the rate of change of real GDP} \\
# {} &                                            mean &   min &    max &       std \\
# Country     &                                                 &       &        &           \\
# \midrule
# China       &                                        7.849091 &  6.11 &  10.64 &  1.413212 \\
# India       &                                        6.845455 &  5.02 &   8.50 &  1.265712 \\
# Japan       &                                        0.672727 & -5.42 &   4.19 &  2.352620 \\
# Philippines &                                        5.950000 &  1.45 &   7.33 &  1.759136 \\
# \bottomrule
# \end{tabular}
#
# \begin{tabular}{lrrrr}
# \toprule
# {} & \multicolumn{4}{l}{Capital investment as percent of GDP} \\
# {} &                                 mean &    min &    max &       std \\
# Country     &                                      &        &        &           \\
# ...
